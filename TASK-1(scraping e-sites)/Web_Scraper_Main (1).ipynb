# %%
# !pip install boolean
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting boolean
#   Downloading boolean-1.1.0.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: boolean
#   Building wheel for boolean (setup.py) ... done
#   Created wheel for boolean: filename=boolean-1.1.0-py3-none-any.whl size=4606 sha256=0409b2a3cccb56c2e1b7a697b531e44303436e5d8f910555bbd1a549e044e875
#   Stored in directory: /root/.cache/pip/wheels/dc/d6/d0/16b790ada0563148d2268431ead23ef596d0034ec132259216
# Successfully built boolean
# Installing collected packages: boolean
# Successfully installed boolean-1.1.0

# %%
# !pip install urlopen
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting urlopen
#   Downloading urlopen-1.0.0.zip (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: urlopen
#   Building wheel for urlopen (setup.py) ... done
#   Created wheel for urlopen: filename=urlopen-1.0.0-py3-none-any.whl size=1409 sha256=fecff3d0b2b4f72f74d454ec74377ff8350deecb0687145e0c63ae3ca3be839d
#   Stored in directory: /root/.cache/pip/wheels/24/9c/4d/ca4e42757ec1b612bebb0ccfd61744f4e77fc4e55e19308869
# Successfully built urlopen
# Installing collected packages: urlopen
# Successfully installed urlopen-1.0.0

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.3.0)

# %%
# !pip install MongoClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement MongoClient (from versions: none)
# ERROR: No matching distribution found for MongoClient

# %% [markdown]
# Importing required libraries

# %%
#import required libraries
import bs4
import requests
import pandas
import pymongo
import json
import csv
import dis
import boolean
import urlopen
import urllib.parse
import numpy

# %%
#Import useful libraries and classes.
from bs4 import BeautifulSoup
import pandas as pd
import urllib.parse
from urllib.request import urlopen
from pymongo import MongoClient
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from dis import dis
from xmlrpc.client import Boolean

# %%
battery = []
model = []
price = []
discount = []
camera = []
ram = []
display = []
processor = []
brand = []

# %%
class Source:
    containers = []
    def __init__(self,containers):
        self.containers = containers


def extract(self,):
        for container in self.containers:
            # inserting model name in the list
            model_name = container.findAll("div", {"class": "_4rR01T"})
            model.append(model_name[0].text.strip())
            brand.append(model_name[0].text.strip().split(' ',1)[0])



            # inserting price and discount similarly
            price_model = container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
            price.append(price_model[0].text.strip())

            info = container.findAll("li", {"class": "rgWa7D"}) 
            ram.append(info[0].text.strip().split(' ', 1)[0])
            display.append(info[1].text.strip().split(' ', 1)[0])
            camera.append(info[2].text.strip())
            battery.append(info[3].text.strip().split(' ', 1)[0])
            processor.append(info[4].text.strip())


            discount_percent = container.findAll("div", {"class": "_3Ay6Sb"})
            # discount.append(discount_percent[0].text.strip())
            if discount_percent == []:
                discount.append("Null")
            else:
                discount.append(discount_percent[0].text)


###############################################################################################################################################################


# html page upload and read in web_page variable.
my_url = "https://www.flipkart.com/search?q=smartphone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_5_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=smartphone%7CMobiles&requestId=20d2e6ea-e392-4e36-a8c1-c7a6eba5b724&as-searchtext=smart&page="


for i in range(1,35):     # to check change the variable to 3 or 4
    my_url = my_url[:-1] + f'{i}'
    print(my_url)
 """
    web_page = uReq(my_url)
    page_html = web_page.read()
    # html parser. It is to beautify the HTML code.
    page_soup = soup(page_html)
    # page_soup

    # read class attribute from web page in containers variable.
    # Print the length of containers.   
    containers = page_soup.findAll("div", {"class": "_2kHMtA"})  
    #print(len(containers))
    cs1 = Source(containers)
    #cs1.extract()

##############################################################################################################################################################

for container in containers:
    # inserting model name in the list
    model_name = container.findAll("div", {"class": "_4rR01T"})
    model.append(model_name[0].text.strip())

    brand.append(model_name[0].text.strip().split(' ', 1)[0])

    # inserting price and discount similarly
    price_model = container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
    price.append(price_model[0].text.strip())

    info = container.findAll("li", {"class": "rgWa7D"}) 
    ram.append(info[0].text.strip().split(' ', 1)[0])
    display.append(info[1].text.strip().split(' ', 1)[0])
    camera.append(info[2].text.strip())
    battery.append(info[3].text.strip().split(' ', 1)[0])
    processor.append(info[4].text.strip())



    discount_percent = container.findAll("div", {"class": "_3Ay6Sb"})
    # discount.append(discount_percent[0].text.strip())
    if discount_percent == []:
        discount.append("Null")
    else:
        discount.append(discount_percent[0].text)"""
# Out:
#   File "<tokenize>", line 46
#     """
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
df = pd.DataFrame(list(zip(model, battery, camera,display,ram ,price, discount, processor, brand)), columns=["Model", "Battery(mah)", "Camera","Display Size", "Ram", "Price", "Discount", "processor", "brand"])

# %%
df = pd.DataFrame(list(zip( brand, model, camera , ram , battery , display ,processor, discount, price )) , columns=[" Brand ", " MOdel " , " Camera" , "Ram", "Battery" , "Display", "processor","discount", "price"])

# %%
df
# Out:
#                                           Model Battery(mah)  \
# 0              vivo T1 44W (Starry Sky, 128 GB)         5000
# 1         vivo T1 44W (Midnight Galaxy, 128 GB)         5000
# 2             POCO M4 Pro 5G (Cool Blue, 64 GB)         5000
# 3         vivo T1 44W (Midnight Galaxy, 128 GB)         5000
# 4               POCO M4 5G (Power Black, 64 GB)         5000
# 5             REDMI 10 (Caribbean Green, 64 GB)         6000
# 6              vivo T1 44W (Starry Sky, 128 GB)         5000
# 7                    POCO M4 5G (Yellow, 64 GB)         5000
# 8         vivo T1 44W (Midnight Galaxy, 128 GB)         5000
# 9                 POCO C31 (Shadow Gray, 64 GB)         5000
# 10              APPLE iPhone 11 (White, 128 GB)          A13
# 11             realme C30 (Bamboo Green, 32 GB)         5000
# 12             realme C30 (Bamboo Green, 32 GB)         5000
# 13                realme C30 (Lake Blue, 32 GB)         5000
# 14                 POCO C31 (Royal Blue, 64 GB)         5000
# 15       Infinix HOT 20 Play (Luna Blue, 64 GB)         6000
# 16    Infinix HOT 20 Play (Racing Black, 64 GB)         6000
# 17  Infinix HOT 20 Play (Fantasy Purple, 64 GB)         6000
# 18              realme C30 (Denim Black, 32 GB)         5000
# 19                realme C30 (Lake Blue, 32 GB)         5000
# 20                POCO C31 (Shadow Gray, 32 GB)         5000
# 21             vivo T1 44W (Starry Sky, 128 GB)         5000
# 22    Infinix HOT 20 Play (Aurora Green, 64 GB)         6000
# 23             REDMI 10 (Midnight Black, 64 GB)         6000
#
#                                   Camera Display Size  Ram    Price Discount  \
# 0   50MP + 2MP + 2MP | 16MP Front Camera        16.36    4  ₹14,499  27% off
# 1   50MP + 2MP + 2MP | 16MP Front Camera        16.36    4  ₹14,499  27% off
# 2         50MP + 8MP | 16MP Front Camera        16.76    4  ₹12,999  23% off
# 3   50MP + 2MP + 2MP | 16MP Front Camera        16.36    6  ₹15,999  23% off
# 4          50MP + 2MP | 8MP Front Camera        16.71    4  ₹11,999  25% off
# 5          50MP + 2MP | 5MP Front Camera        17.02    4   ₹9,299  38% off
# 6   50MP + 2MP + 2MP | 16MP Front Camera        16.36    6  ₹15,999  23% off
# 7          50MP + 2MP | 8MP Front Camera        16.71    4  ₹11,999  25% off
# 8   50MP + 2MP + 2MP | 16MP Front Camera        16.36    8  ₹17,999  24% off
# 9    13MP + 2MP + 2MP | 5MP Front Camera        16.59    4   ₹7,499  37% off
# 10       12MP + 12MP | 12MP Front Camera        15.49  128  ₹47,199   3% off
# 11    8MP Rear Camera | 5MP Front Camera        16.51    2   ₹5,749  32% off
# 12    8MP Rear Camera | 5MP Front Camera        16.51    3   ₹6,749  27% off
# 13    8MP Rear Camera | 5MP Front Camera        16.51    2   ₹5,749  32% off
# 14   13MP + 2MP + 2MP | 5MP Front Camera        16.59    4   ₹7,499  37% off
# 15     13Mp + AI Lens | 8MP Front Camera        17.32    4   ₹8,199  31% off
# 16     13Mp + AI Lens | 8MP Front Camera        17.32    4   ₹8,199  31% off
# 17     13Mp + AI Lens | 8MP Front Camera        17.32    4   ₹8,199  31% off
# 18    8MP Rear Camera | 5MP Front Camera        16.51    3   ₹6,749  27% off
# 19    8MP Rear Camera | 5MP Front Camera        16.51    3   ₹6,749  27% off
# 20   13MP + 2MP + 2MP | 5MP Front Camera        16.59    3   ₹6,499  40% off
# 21  50MP + 2MP + 2MP | 16MP Front Camera        16.36    8  ₹17,999  24% off
# 22     13Mp + AI Lens | 8MP Front Camera        17.32    4   ₹8,199  31% off
# 23         50MP + 2MP | 5MP Front Camera        17.02    4   ₹9,299  38% off
#
#                             processor    brand
# 0   Qualcomm Snapdragon 680 Processor     vivo
# 1   Qualcomm Snapdragon 680 Processor     vivo
# 2    Mediatek Dimensity 810 Processor     POCO
# 3   Qualcomm Snapdragon 680 Processor     vivo
# 4    Mediatek Dimensity 700 Processor     POCO
# 5   Qualcomm Snapdragon 680 Processor    REDMI
# 6   Qualcomm Snapdragon 680 Processor     vivo
# 7    Mediatek Dimensity 700 Processor     POCO
# 8   Qualcomm Snapdragon 680 Processor     vivo
# 9        MediaTek Helio G35 Processor     POCO
# 10           Brand Warranty of 1 Year    APPLE
# 11              Unisoc T612 Processor   realme
# 12              Unisoc T612 Processor   realme
# 13              Unisoc T612 Processor   realme
# 14             MediaTek G35 Processor     POCO
# 15             MediaTek G37 Processor  Infinix
# 16             MediaTek G37 Processor  Infinix
# 17             MediaTek G37 Processor  Infinix
# 18              Unisoc T612 Processor   realme
# 19              Unisoc T612 Processor   realme
# 20       MediaTek Helio G35 Processor     POCO
# 21  Qualcomm Snapdragon 680 Processor     vivo
# 22             MediaTek G37 Processor  Infinix
# 23  Qualcomm Snapdragon 680 Processor    REDMI

# %%
file_name = "Flipkart2.xlsx"

df.to_excel(file_name)

# %%
df
# Out:
#      Brand                                        MOdel   \
# 0      vivo             vivo T1 44W (Starry Sky, 128 GB)
# 1      vivo        vivo T1 44W (Midnight Galaxy, 128 GB)
# 2      POCO            POCO M4 Pro 5G (Cool Blue, 64 GB)
# 3      vivo        vivo T1 44W (Midnight Galaxy, 128 GB)
# 4      POCO              POCO M4 5G (Power Black, 64 GB)
# 5     REDMI            REDMI 10 (Caribbean Green, 64 GB)
# 6      vivo             vivo T1 44W (Starry Sky, 128 GB)
# 7      POCO                   POCO M4 5G (Yellow, 64 GB)
# 8      vivo        vivo T1 44W (Midnight Galaxy, 128 GB)
# 9      POCO                POCO C31 (Shadow Gray, 64 GB)
# 10    APPLE              APPLE iPhone 11 (White, 128 GB)
# 11   realme             realme C30 (Bamboo Green, 32 GB)
# 12   realme             realme C30 (Bamboo Green, 32 GB)
# 13   realme                realme C30 (Lake Blue, 32 GB)
# 14     POCO                 POCO C31 (Royal Blue, 64 GB)
# 15  Infinix       Infinix HOT 20 Play (Luna Blue, 64 GB)
# 16  Infinix    Infinix HOT 20 Play (Racing Black, 64 GB)
# 17  Infinix  Infinix HOT 20 Play (Fantasy Purple, 64 GB)
# 18   realme              realme C30 (Denim Black, 32 GB)
# 19   realme                realme C30 (Lake Blue, 32 GB)
# 20     POCO                POCO C31 (Shadow Gray, 32 GB)
# 21     vivo             vivo T1 44W (Starry Sky, 128 GB)
# 22  Infinix    Infinix HOT 20 Play (Aurora Green, 64 GB)
# 23    REDMI             REDMI 10 (Midnight Black, 64 GB)
#
#                                   Camera  Ram Battery Display  \
# 0   50MP + 2MP + 2MP | 16MP Front Camera    4    5000   16.36
# 1   50MP + 2MP + 2MP | 16MP Front Camera    4    5000   16.36
# 2         50MP + 8MP | 16MP Front Camera    4    5000   16.76
# 3   50MP + 2MP + 2MP | 16MP Front Camera    6    5000   16.36
# 4          50MP + 2MP | 8MP Front Camera    4    5000   16.71
# 5          50MP + 2MP | 5MP Front Camera    4    6000   17.02
# 6   50MP + 2MP + 2MP | 16MP Front Camera    6    5000   16.36
# 7          50MP + 2MP | 8MP Front Camera    4    5000   16.71
# 8   50MP + 2MP + 2MP | 16MP Front Camera    8    5000   16.36
# 9    13MP + 2MP + 2MP | 5MP Front Camera    4    5000   16.59
# 10       12MP + 12MP | 12MP Front Camera  128     A13   15.49
# 11    8MP Rear Camera | 5MP Front Camera    2    5000   16.51
# 12    8MP Rear Camera | 5MP Front Camera    3    5000   16.51
# 13    8MP Rear Camera | 5MP Front Camera    2    5000   16.51
# 14   13MP + 2MP + 2MP | 5MP Front Camera    4    5000   16.59
# 15     13Mp + AI Lens | 8MP Front Camera    4    6000   17.32
# 16     13Mp + AI Lens | 8MP Front Camera    4    6000   17.32
# 17     13Mp + AI Lens | 8MP Front Camera    4    6000   17.32
# 18    8MP Rear Camera | 5MP Front Camera    3    5000   16.51
# 19    8MP Rear Camera | 5MP Front Camera    3    5000   16.51
# 20   13MP + 2MP + 2MP | 5MP Front Camera    3    5000   16.59
# 21  50MP + 2MP + 2MP | 16MP Front Camera    8    5000   16.36
# 22     13Mp + AI Lens | 8MP Front Camera    4    6000   17.32
# 23         50MP + 2MP | 5MP Front Camera    4    6000   17.02
#
#                             processor discount    price
# 0   Qualcomm Snapdragon 680 Processor  27% off  ₹14,499
# 1   Qualcomm Snapdragon 680 Processor  27% off  ₹14,499
# 2    Mediatek Dimensity 810 Processor  23% off  ₹12,999
# 3   Qualcomm Snapdragon 680 Processor  23% off  ₹15,999
# 4    Mediatek Dimensity 700 Processor  25% off  ₹11,999
# 5   Qualcomm Snapdragon 680 Processor  38% off   ₹9,299
# 6   Qualcomm Snapdragon 680 Processor  23% off  ₹15,999
# 7    Mediatek Dimensity 700 Processor  25% off  ₹11,999
# 8   Qualcomm Snapdragon 680 Processor  24% off  ₹17,999
# 9        MediaTek Helio G35 Processor  37% off   ₹7,499
# 10           Brand Warranty of 1 Year   3% off  ₹47,199
# 11              Unisoc T612 Processor  32% off   ₹5,749
# 12              Unisoc T612 Processor  27% off   ₹6,749
# 13              Unisoc T612 Processor  32% off   ₹5,749
# 14             MediaTek G35 Processor  37% off   ₹7,499
# 15             MediaTek G37 Processor  31% off   ₹8,199
# 16             MediaTek G37 Processor  31% off   ₹8,199
# 17             MediaTek G37 Processor  31% off   ₹8,199
# 18              Unisoc T612 Processor  27% off   ₹6,749
# 19              Unisoc T612 Processor  27% off   ₹6,749
# 20       MediaTek Helio G35 Processor  40% off   ₹6,499
# 21  Qualcomm Snapdragon 680 Processor  24% off  ₹17,999
# 22             MediaTek G37 Processor  31% off   ₹8,199
# 23  Qualcomm Snapdragon 680 Processor  38% off   ₹9,299

# %%
class Source:
    containers = []
    def __init__(self,containers):
        self.containers = containers


def extract(self,):
        for container in self.containers:
            # inserting model name in the list
            model_name = container.findAll("div", {"class": "_4rR01T"})
            model.append(model_name[0].text.strip())
            # inserting price and discount similarly
            price_model = container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
            price.append(price_model[0].text.strip())

            info = container.findAll("li", {"class": "rgWa7D"}) 
            ram.append(info[0].text.strip().split(' ', 1)[0])
            display.append(info[1].text.strip().split(' ', 1)[0])
            camera.append(info[2].text.strip())
            battery.append(info[3].text.strip().split(' ', 1)[0])



            discount_percent = container.findAll("div", {"class": "_3Ay6Sb"})
            # discount.append(discount_percent[0].text.strip())
            if discount_percent == []:
                discount.append("Null")
            else:
                discount.append(discount_percent[0].text)


###############################################################################################################################################################


# html page upload and read in web_page variable.
my_url = "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1&page=1"


for i in range(1,100):     # to check change the variable to 3 or 4
    my_url = my_url[:-1] + f'{i}'

    web_page = uReq(my_url)
    page_html = web_page.read()
    # html parser. It is to beautify the HTML code.
    page_soup = soup(page_html)
    # page_soup

    # read class attribute from web page in containers variable.
    # Print the length of containers.   
    containers = page_soup.findAll("div", {"class": "_2kHMtA"})  
    #print(len(containers))
    cs1 = Source(containers)
    #cs1.extract()

##############################################################################################################################################################

for container in containers:
    # inserting model name in the list
    model_name = container.findAll("div", {"class": "_4rR01T"})
    model.append(model_name[0].text.strip())
    # inserting price and discount similarly
    price_model = container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
    price.append(price_model[0].text.strip())

    info = container.findAll("li", {"class": "rgWa7D"}) 
    ram.append(info[0].text.strip().split(' ', 1)[0])
    display.append(info[1].text.strip().split(' ', 1)[0])
    camera.append(info[2].text.strip())
    battery.append(info[3].text.strip().split(' ', 1)[0])



    discount_percent = container.findAll("div", {"class": "_3Ay6Sb"})
    # discount.append(discount_percent[0].text.strip())
    if discount_percent == []:
        discount.append("Null")
    else:
        discount.append(discount_percent[0].text)
